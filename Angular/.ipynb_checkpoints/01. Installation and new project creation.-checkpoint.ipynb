# %% [markdown]
# ## Installation
#
# Before Angular installation, please check the must have prerequisites:
#
# https://angular.dev/installation#prerequisites
#
# #### To install Anuglar enter below command in command line:
#
# npm install -g @angular/cli
#
# ## Project initialization
#
# To create project enter the command:
#
# ng new <project-name>
#
# You will have to answer few confirugation questions and after that the installation will start.
